# %%
# Install latest version from GitHub
# !pip install -q -U git+https://github.com/jdvelasq/techminer

# %% [markdown]
# # Ocurrence

# %%
import matplotlib.pyplot as plt
import pandas as pd

from techminer import DataFrame, Plot, heatmap, Map

#
# Data loading
#
df = DataFrame(
    pd.read_json(
        "https://raw.githubusercontent.com/jdvelasq/techminer/master/data/tutorial/"
        + "cleaned-data.json",
        orient="records",
        lines=True,
    )
)

#
# Columns of the dataframe
#
df.columns
# Out:
# Index(['Authors', 'Author(s) ID', 'Title', 'Year', 'Source title', 'Volume',
#        'Issue', 'Art. No.', 'Page start', 'Page end', 'Page count', 'Cited by',
#        'DOI', 'Affiliations', 'Document Type', 'Access Type', 'Source', 'EID',
#        'Abstract', 'Author Keywords', 'Index Keywords', 'References',
#        'keywords', 'CONF', 'fingerprint', 'keywords_cleaned', 'ID',
#        'top_10_Authors_freq', 'top_10_keywords_freq',
#        'top_10_Source_title_freq', 'top_10_Authors_cited_by',
#        'top_10_keywords_cited_by', 'top_10_Source_title_cited_by'],
#       dtype='object')

# %% [markdown]
# ## Authors

# %%
top_authors = df.documents_by_term("Authors").head(10).Authors
top_authors
# Out:
# 0       Arevalo A.
# 1       Gabbouj M.
# 2     Hernandez G.
# 3     Hussain A.J.
# 4     Iosifidis A.
# 5    Kanniainen J.
# 6          Leon D.
# 7          Nino J.
# 8      Passalis N.
# 9      Sandoval J.
# Name: Authors, dtype: object

# %%
matrix = df.occurrence(column="Authors", as_matrix=True)
matrix = matrix.loc[top_authors, top_authors]
heatmap(matrix)
# Out:
# <style  type="text/css" >
#     #T_8f434c02_9afd_11ea_9643_0242ac110002row0_col0 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_8f434c02_9afd_11ea_9643_0242ac110002row0_col1 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_8f434c02_9afd_11ea_9643_0242ac110002row0_col2 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_8f434c02_9afd_11ea_9643_0242ac110002row0_col3 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_8f434c02_9afd_11ea_9643_0242ac110002row0_col4 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_8f434c02_9afd_11ea_9643_0242ac110002row0_col5 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_8f434c02_9afd_11ea_9643_0242ac110002row0_col6 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_8f434c02_9afd_11ea_9643_0242ac110002row0_col7 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_8f434c02_9afd_11ea_9643_0242ac110002row0_col8 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_8f434c02_9afd_11ea_9643_0242ac110002row0_col9 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_8f434c02_9afd_11ea_9643_0242ac110002row1_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_8f434c02_9afd_11ea_9643_0242ac110002row1_col1 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_8f434c02_9afd_11ea_9643_0242ac110002row1_col2 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_8f434c02_9afd_11ea_9643_0242ac110002row1_col3 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_8f434c02_9afd_11ea_9643_0242ac110002row1_col4 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_8f434c02_9afd_11ea_9643_0242ac110002row1_col5 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_8f434c02_9afd_11ea_9643_0242ac110002row1_col6 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_8f434c02_9afd_11ea_9643_0242ac110002row1_col7 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_8f434c02_9afd_11ea_9643_0242ac110002row1_col8 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_8f434c02_9afd_11ea_9643_0242ac110002row1_col9 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_8f434c02_9afd_11ea_9643_0242ac110002row2_col0 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_8f434c02_9afd_11ea_9643_0242ac110002row2_col1 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_8f434c02_9afd_11ea_9643_0242ac110002row2_col2 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_8f434c02_9afd_11ea_9643_0242ac110002row2_col3 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_8f434c02_9afd_11ea_9643_0242ac110002row2_col4 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_8f434c02_9afd_11ea_9643_0242ac110002row2_col5 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_8f434c02_9afd_11ea_9643_0242ac110002row2_col6 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_8f434c02_9afd_11ea_9643_0242ac110002row2_col7 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_8f434c02_9afd_11ea_9643_0242ac110002row2_col8 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_8f434c02_9afd_11ea_9643_0242ac110002row2_col9 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_8f434c02_9afd_11ea_9643_0242ac110002row3_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_8f434c02_9afd_11ea_9643_0242ac110002row3_col1 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_8f434c02_9afd_11ea_9643_0242ac110002row3_col2 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_8f434c02_9afd_11ea_9643_0242ac110002row3_col3 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_8f434c02_9afd_11ea_9643_0242ac110002row3_col4 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_8f434c02_9afd_11ea_9643_0242ac110002row3_col5 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_8f434c02_9afd_11ea_9643_0242ac110002row3_col6 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_8f434c02_9afd_11ea_9643_0242ac110002row3_col7 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_8f434c02_9afd_11ea_9643_0242ac110002row3_col8 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_8f434c02_9afd_11ea_9643_0242ac110002row3_col9 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_8f434c02_9afd_11ea_9643_0242ac110002row4_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_8f434c02_9afd_11ea_9643_0242ac110002row4_col1 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_8f434c02_9afd_11ea_9643_0242ac110002row4_col2 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_8f434c02_9afd_11ea_9643_0242ac110002row4_col3 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_8f434c02_9afd_11ea_9643_0242ac110002row4_col4 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_8f434c02_9afd_11ea_9643_0242ac110002row4_col5 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_8f434c02_9afd_11ea_9643_0242ac110002row4_col6 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_8f434c02_9afd_11ea_9643_0242ac110002row4_col7 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_8f434c02_9afd_11ea_9643_0242ac110002row4_col8 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_8f434c02_9afd_11ea_9643_0242ac110002row4_col9 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_8f434c02_9afd_11ea_9643_0242ac110002row5_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_8f434c02_9afd_11ea_9643_0242ac110002row5_col1 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_8f434c02_9afd_11ea_9643_0242ac110002row5_col2 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_8f434c02_9afd_11ea_9643_0242ac110002row5_col3 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_8f434c02_9afd_11ea_9643_0242ac110002row5_col4 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_8f434c02_9afd_11ea_9643_0242ac110002row5_col5 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_8f434c02_9afd_11ea_9643_0242ac110002row5_col6 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_8f434c02_9afd_11ea_9643_0242ac110002row5_col7 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_8f434c02_9afd_11ea_9643_0242ac110002row5_col8 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_8f434c02_9afd_11ea_9643_0242ac110002row5_col9 {
#             background-color:  #f7fbff;
#             color:  #000000;

# %%
plt.figure(figsize=(10, 8))
Plot(matrix).heatmap(cmap='Blues')

# %%
plt.figure(figsize=(10, 10))
dic1 = df.occurrence_map(column="Authors", include_only=top_authors)
dic2 = dict(
    term_props={"node_color": "red"},
    label_docs_props={"color": "k"},
    label_term_props=dict(ma="left", rotation=0, fontsize=10, disp=3, bbox=None),
)
kwargs = {**dic1, **dic2}
Map().ocurrence_map(**kwargs)

# %% [markdown]
# ## Keywords

# %%
#
# Analysis for top 10 most frequent keywords
#
top_keywords = df.documents_by_term("keywords_cleaned", sep=';').head(10).keywords_cleaned
top_keywords
# Out:
# 0                       forecasting
# 1                       time series
# 2                            market
# 3                     deep learning
# 4                   neural networks
# 5                           trading
# 6                          commerce
# 7         recurrent neural networks
# 8    long short term memory network
# 9                        prediction
# Name: keywords_cleaned, dtype: object

# %%
matrix = df.occurrence(column="keywords_cleaned", sep=';', as_matrix=True)
matrix = matrix.loc[top_keywords, top_keywords]
heatmap(matrix)
# Out:
# <style  type="text/css" >
#     #T_92a152fe_9afd_11ea_9643_0242ac110002row0_col0 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_92a152fe_9afd_11ea_9643_0242ac110002row0_col1 {
#             background-color:  #2373b6;
#             color:  #f1f1f1;
#         }    #T_92a152fe_9afd_11ea_9643_0242ac110002row0_col2 {
#             background-color:  #2373b6;
#             color:  #f1f1f1;
#         }    #T_92a152fe_9afd_11ea_9643_0242ac110002row0_col3 {
#             background-color:  #2474b7;
#             color:  #f1f1f1;
#         }    #T_92a152fe_9afd_11ea_9643_0242ac110002row0_col4 {
#             background-color:  #3b8bc2;
#             color:  #000000;
#         }    #T_92a152fe_9afd_11ea_9643_0242ac110002row0_col5 {
#             background-color:  #2777b8;
#             color:  #000000;
#         }    #T_92a152fe_9afd_11ea_9643_0242ac110002row0_col6 {
#             background-color:  #3989c1;
#             color:  #000000;
#         }    #T_92a152fe_9afd_11ea_9643_0242ac110002row0_col7 {
#             background-color:  #1966ad;
#             color:  #f1f1f1;
#         }    #T_92a152fe_9afd_11ea_9643_0242ac110002row0_col8 {
#             background-color:  #1966ad;
#             color:  #f1f1f1;
#         }    #T_92a152fe_9afd_11ea_9643_0242ac110002row0_col9 {
#             background-color:  #0b559f;
#             color:  #f1f1f1;
#         }    #T_92a152fe_9afd_11ea_9643_0242ac110002row1_col0 {
#             background-color:  #5fa6d1;
#             color:  #000000;
#         }    #T_92a152fe_9afd_11ea_9643_0242ac110002row1_col1 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_92a152fe_9afd_11ea_9643_0242ac110002row1_col2 {
#             background-color:  #7cb7da;
#             color:  #000000;
#         }    #T_92a152fe_9afd_11ea_9643_0242ac110002row1_col3 {
#             background-color:  #4997c9;
#             color:  #000000;
#         }    #T_92a152fe_9afd_11ea_9643_0242ac110002row1_col4 {
#             background-color:  #3787c0;
#             color:  #000000;
#         }    #T_92a152fe_9afd_11ea_9643_0242ac110002row1_col5 {
#             background-color:  #6fb0d7;
#             color:  #000000;
#         }    #T_92a152fe_9afd_11ea_9643_0242ac110002row1_col6 {
#             background-color:  #5fa6d1;
#             color:  #000000;
#         }    #T_92a152fe_9afd_11ea_9643_0242ac110002row1_col7 {
#             background-color:  #4997c9;
#             color:  #000000;
#         }    #T_92a152fe_9afd_11ea_9643_0242ac110002row1_col8 {
#             background-color:  #6aaed6;
#             color:  #000000;
#         }    #T_92a152fe_9afd_11ea_9643_0242ac110002row1_col9 {
#             background-color:  #2272b6;
#             color:  #f1f1f1;
#         }    #T_92a152fe_9afd_11ea_9643_0242ac110002row2_col0 {
#             background-color:  #a6cee4;
#             color:  #000000;
#         }    #T_92a152fe_9afd_11ea_9643_0242ac110002row2_col1 {
#             background-color:  #afd1e7;
#             color:  #000000;
#         }    #T_92a152fe_9afd_11ea_9643_0242ac110002row2_col2 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_92a152fe_9afd_11ea_9643_0242ac110002row2_col3 {
#             background-color:  #68acd5;
#             color:  #000000;
#         }    #T_92a152fe_9afd_11ea_9643_0242ac110002row2_col4 {
#             background-color:  #68acd5;
#             color:  #000000;
#         }    #T_92a152fe_9afd_11ea_9643_0242ac110002row2_col5 {
#             background-color:  #3383be;
#             color:  #000000;
#         }    #T_92a152fe_9afd_11ea_9643_0242ac110002row2_col6 {
#             background-color:  #1b69af;
#             color:  #f1f1f1;
#         }    #T_92a152fe_9afd_11ea_9643_0242ac110002row2_col7 {
#             background-color:  #75b4d8;
#             color:  #000000;
#         }    #T_92a152fe_9afd_11ea_9643_0242ac110002row2_col8 {
#             background-color:  #519ccc;
#             color:  #000000;
#         }    #T_92a152fe_9afd_11ea_9643_0242ac110002row2_col9 {
#             background-color:  #71b1d7;
#             color:  #000000;
#         }    #T_92a152fe_9afd_11ea_9643_0242ac110002row3_col0 {
#             background-color:  #cddff1;
#             color:  #000000;
#         }    #T_92a152fe_9afd_11ea_9643_0242ac110002row3_col1 {
#             background-color:  #b9d6ea;
#             color:  #000000;
#         }    #T_92a152fe_9afd_11ea_9643_0242ac110002row3_col2 {
#             background-color:  #b0d2e7;
#             color:  #000000;
#         }    #T_92a152fe_9afd_11ea_9643_0242ac110002row3_col3 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_92a152fe_9afd_11ea_9643_0242ac110002row3_col4 {
#             background-color:  #b2d2e8;
#             color:  #000000;
#         }    #T_92a152fe_9afd_11ea_9643_0242ac110002row3_col5 {
#             background-color:  #bed8ec;
#             color:  #000000;
#         }    #T_92a152fe_9afd_11ea_9643_0242ac110002row3_col6 {
#             background-color:  #7ab6d9;
#             color:  #000000;
#         }    #T_92a152fe_9afd_11ea_9643_0242ac110002row3_col7 {
#             background-color:  #e7f1fa;
#             color:  #000000;
#         }    #T_92a152fe_9afd_11ea_9643_0242ac110002row3_col8 {
#             background-color:  #cee0f2;
#             color:  #000000;
#         }    #T_92a152fe_9afd_11ea_9643_0242ac110002row3_col9 {
#             background-color:  #b2d2e8;
#             color:  #000000;
#         }    #T_92a152fe_9afd_11ea_9643_0242ac110002row4_col0 {
#             background-color:  #ddeaf7;
#             color:  #000000;
#         }    #T_92a152fe_9afd_11ea_9643_0242ac110002row4_col1 {
#             background-color:  #afd1e7;
#             color:  #000000;
#         }    #T_92a152fe_9afd_11ea_9643_0242ac110002row4_col2 {
#             background-color:  #bdd7ec;
#             color:  #000000;
#         }    #T_92a152fe_9afd_11ea_9643_0242ac110002row4_col3 {
#             background-color:  #c2d9ee;
#             color:  #000000;
#         }    #T_92a152fe_9afd_11ea_9643_0242ac110002row4_col4 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_92a152fe_9afd_11ea_9643_0242ac110002row4_col5 {
#             background-color:  #81badb;
#             color:  #000000;
#         }    #T_92a152fe_9afd_11ea_9643_0242ac110002row4_col6 {
#             background-color:  #99c7e0;
#             color:  #000000;
#         }    #T_92a152fe_9afd_11ea_9643_0242ac110002row4_col7 {
#             background-color:  #95c5df;
#             color:  #000000;
#         }    #T_92a152fe_9afd_11ea_9643_0242ac110002row4_col8 {
#             background-color:  #edf4fc;
#             color:  #000000;
#         }    #T_92a152fe_9afd_11ea_9643_0242ac110002row4_col9 {
#             background-color:  #a9cfe5;
#             color:  #000000;
#         }    #T_92a152fe_9afd_11ea_9643_0242ac110002row5_col0 {
#             background-color:  #d5e5f4;
#             color:  #000000;
#         }    #T_92a152fe_9afd_11ea_9643_0242ac110002row5_col1 {
#             background-color:  #d3e3f3;
#             color:  #000000;
#         }    #T_92a152fe_9afd_11ea_9643_0242ac110002row5_col2 {
#             background-color:  #7cb7da;
#             color:  #000000;
#         }    #T_92a152fe_9afd_11ea_9643_0242ac110002row5_col3 {
#             background-color:  #bcd7eb;
#             color:  #000000;
#         }    #T_92a152fe_9afd_11ea_9643_0242ac110002row5_col4 {
#             background-color:  #75b4d8;
#             color:  #000000;
#         }    #T_92a152fe_9afd_11ea_9643_0242ac110002row5_col5 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_92a152fe_9afd_11ea_9643_0242ac110002row5_col6 {
#             background-color:  #66abd4;
#             color:  #000000;
#         }    #T_92a152fe_9afd_11ea_9643_0242ac110002row5_col7 {
#             background-color:  #b2d2e8;
#             color:  #000000;
#         }    #T_92a152fe_9afd_11ea_9643_0242ac110002row5_col8 {
#             background-color:  #8cc0dd;
#             color:  #000000;
#         }    #T_92a152fe_9afd_11ea_9643_0242ac110002row5_col9 {
#             background-color:  #cadef0;
#             color:  #000000;

# %%
plt.figure(figsize=(9, 8))
Plot(matrix).heatmap(cmap='Blues')
