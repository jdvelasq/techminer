# %%
# Install latest version from GitHub
# !pip install -q -U git+https://github.com/jdvelasq/techminer

# %% [markdown]
# # Factor analysis (Experimental)

# %%
import matplotlib.pyplot as plt
import pandas as pd

from techminer import DataFrame, Plot, heatmap

#
# Data loading
#
df = DataFrame(
    pd.read_json(
        "https://raw.githubusercontent.com/jdvelasq/techminer/master/data/tutorial/"
        + "cleaned-data.json",
        orient="records",
        lines=True,
    )
)

#
# Columns of the dataframe
#
df.columns
# Out:
# Index(['Authors', 'Author(s) ID', 'Title', 'Year', 'Source title', 'Volume',
#        'Issue', 'Art. No.', 'Page start', 'Page end', 'Page count', 'Cited by',
#        'DOI', 'Affiliations', 'Document Type', 'Access Type', 'Source', 'EID',
#        'Abstract', 'Author Keywords', 'Index Keywords', 'References',
#        'keywords', 'CONF', 'fingerprint', 'keywords_cleaned', 'ID',
#        'top_10_Authors_freq', 'top_10_keywords_freq',
#        'top_10_Source_title_freq', 'top_10_Authors_cited_by',
#        'top_10_keywords_cited_by', 'top_10_Source_title_cited_by'],
#       dtype='object')

# %% [markdown]
# ## Authors

# %%
#
# Top 20 most frequent authors
#
top_authors = df.documents_by_term('Authors').head(20).Authors
top_authors
# Out:
# 0        Arevalo A.
# 1        Gabbouj M.
# 2      Hernandez G.
# 3      Hussain A.J.
# 4      Iosifidis A.
# 5     Kanniainen J.
# 6           Leon D.
# 7           Nino J.
# 8       Passalis N.
# 9       Sandoval J.
# 10         Tefas A.
# 11      Al-Askar H.
# 12    Al-Jumeily D.
# 13         Bohte S.
# 14      Borovykh A.
# 15            Bu H.
# 16        Dash P.K.
# 17     Di Persio L.
# 18       Honchar O.
# 19        Liu C.-L.
# Name: Authors, dtype: object

# %%
matrix = df.factor_analysis(column="Authors", sep=",", n_components=5)
matrix = matrix.loc[top_authors,:]
heatmap(matrix)
# Out:
# <style  type="text/css" >
#     #T_1b41b616_9b04_11ea_82ae_0242ac110002row0_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_1b41b616_9b04_11ea_82ae_0242ac110002row0_col1 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_1b41b616_9b04_11ea_82ae_0242ac110002row0_col2 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_1b41b616_9b04_11ea_82ae_0242ac110002row0_col3 {
#             background-color:  #083471;
#             color:  #f1f1f1;
#         }    #T_1b41b616_9b04_11ea_82ae_0242ac110002row0_col4 {
#             background-color:  #e7f1fa;
#             color:  #000000;
#         }    #T_1b41b616_9b04_11ea_82ae_0242ac110002row1_col0 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_1b41b616_9b04_11ea_82ae_0242ac110002row1_col1 {
#             background-color:  #d4e4f4;
#             color:  #000000;
#         }    #T_1b41b616_9b04_11ea_82ae_0242ac110002row1_col2 {
#             background-color:  #65aad4;
#             color:  #000000;
#         }    #T_1b41b616_9b04_11ea_82ae_0242ac110002row1_col3 {
#             background-color:  #083471;
#             color:  #f1f1f1;
#         }    #T_1b41b616_9b04_11ea_82ae_0242ac110002row1_col4 {
#             background-color:  #e7f1fa;
#             color:  #000000;
#         }    #T_1b41b616_9b04_11ea_82ae_0242ac110002row2_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_1b41b616_9b04_11ea_82ae_0242ac110002row2_col1 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_1b41b616_9b04_11ea_82ae_0242ac110002row2_col2 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_1b41b616_9b04_11ea_82ae_0242ac110002row2_col3 {
#             background-color:  #083471;
#             color:  #f1f1f1;
#         }    #T_1b41b616_9b04_11ea_82ae_0242ac110002row2_col4 {
#             background-color:  #e7f1fa;
#             color:  #000000;
#         }    #T_1b41b616_9b04_11ea_82ae_0242ac110002row3_col0 {
#             background-color:  #dceaf6;
#             color:  #000000;
#         }    #T_1b41b616_9b04_11ea_82ae_0242ac110002row3_col1 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_1b41b616_9b04_11ea_82ae_0242ac110002row3_col2 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_1b41b616_9b04_11ea_82ae_0242ac110002row3_col3 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_1b41b616_9b04_11ea_82ae_0242ac110002row3_col4 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_1b41b616_9b04_11ea_82ae_0242ac110002row4_col0 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_1b41b616_9b04_11ea_82ae_0242ac110002row4_col1 {
#             background-color:  #d4e4f4;
#             color:  #000000;
#         }    #T_1b41b616_9b04_11ea_82ae_0242ac110002row4_col2 {
#             background-color:  #65aad4;
#             color:  #000000;
#         }    #T_1b41b616_9b04_11ea_82ae_0242ac110002row4_col3 {
#             background-color:  #083471;
#             color:  #f1f1f1;
#         }    #T_1b41b616_9b04_11ea_82ae_0242ac110002row4_col4 {
#             background-color:  #e7f1fa;
#             color:  #000000;
#         }    #T_1b41b616_9b04_11ea_82ae_0242ac110002row5_col0 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_1b41b616_9b04_11ea_82ae_0242ac110002row5_col1 {
#             background-color:  #d4e4f4;
#             color:  #000000;
#         }    #T_1b41b616_9b04_11ea_82ae_0242ac110002row5_col2 {
#             background-color:  #65aad4;
#             color:  #000000;
#         }    #T_1b41b616_9b04_11ea_82ae_0242ac110002row5_col3 {
#             background-color:  #083471;
#             color:  #f1f1f1;
#         }    #T_1b41b616_9b04_11ea_82ae_0242ac110002row5_col4 {
#             background-color:  #e7f1fa;
#             color:  #000000;
#         }    #T_1b41b616_9b04_11ea_82ae_0242ac110002row6_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_1b41b616_9b04_11ea_82ae_0242ac110002row6_col1 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_1b41b616_9b04_11ea_82ae_0242ac110002row6_col2 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_1b41b616_9b04_11ea_82ae_0242ac110002row6_col3 {
#             background-color:  #083471;
#             color:  #f1f1f1;
#         }    #T_1b41b616_9b04_11ea_82ae_0242ac110002row6_col4 {
#             background-color:  #e7f1fa;
#             color:  #000000;
#         }    #T_1b41b616_9b04_11ea_82ae_0242ac110002row7_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_1b41b616_9b04_11ea_82ae_0242ac110002row7_col1 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_1b41b616_9b04_11ea_82ae_0242ac110002row7_col2 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_1b41b616_9b04_11ea_82ae_0242ac110002row7_col3 {
#             background-color:  #083471;
#             color:  #f1f1f1;
#         }    #T_1b41b616_9b04_11ea_82ae_0242ac110002row7_col4 {
#             background-color:  #e7f1fa;
#             color:  #000000;
#         }    #T_1b41b616_9b04_11ea_82ae_0242ac110002row8_col0 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_1b41b616_9b04_11ea_82ae_0242ac110002row8_col1 {
#             background-color:  #d4e4f4;
#             color:  #000000;
#         }    #T_1b41b616_9b04_11ea_82ae_0242ac110002row8_col2 {
#             background-color:  #65aad4;
#             color:  #000000;
#         }    #T_1b41b616_9b04_11ea_82ae_0242ac110002row8_col3 {
#             background-color:  #083471;
#             color:  #f1f1f1;
#         }    #T_1b41b616_9b04_11ea_82ae_0242ac110002row8_col4 {
#             background-color:  #e7f1fa;
#             color:  #000000;
#         }    #T_1b41b616_9b04_11ea_82ae_0242ac110002row9_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_1b41b616_9b04_11ea_82ae_0242ac110002row9_col1 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_1b41b616_9b04_11ea_82ae_0242ac110002row9_col2 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_1b41b616_9b04_11ea_82ae_0242ac110002row9_col3 {
#             background-color:  #083471;
#             color:  #f1f1f1;
#         }    #T_1b41b616_9b04_11ea_82ae_0242ac110002row9_col4 {
#             background-color:  #e7f1fa;
#             color:  #000000;
#         }    #T_1b41b616_9b04_11ea_82ae_0242ac110002row10_col0 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_1b41b616_9b04_11ea_82ae_0242ac110002row10_col1 {
#             background-color:  #d4e4f4;
#             color:  #000000;
#         }    #T_1b41b616_9b04_11ea_82ae_0242ac110002row10_col2 {
#             background-color:  #65aad4;
#             color:  #000000;
#         }    #T_1b41b616_9b04_11ea_82ae_0242ac110002row10_col3 {
#             background-color:  #083471;
#             color:  #f1f1f1;
#         }    #T_1b41b616_9b04_11ea_82ae_0242ac110002row10_col4 {
#             background-color:  #e7f1fa;
#             color:  #000000;
#         }    #T_1b41b616_9b04_11ea_82ae_0242ac110002row11_col0 {
#             background-color:  #dce9f6;
#             color:  #000000;
#         }    #T_1b41b616_9b04_11ea_82ae_0242ac110002row11_col1 {
#             background-color:  #f5fafe;
#             color:  #000000;
#         }    #T_1b41b616_9b04_11ea_82ae_0242ac110002row11_col2 {
#             background-color:  #f0f6fd;
#             color:  #000000;
#         }    #T_1b41b616_9b04_11ea_82ae_0242ac110002row11_col3 {
#             background-color:  #d1e2f3;
#             color:  #000000;
#         }    #T_1b41b616_9b04_11ea_82ae_0242ac110002row11_col4 {
#             background-color:  #135fa7;
#             color:  #f
